# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census
import gmaps
import os
from us import states
from pathlib import Path
# %matplotlib inline
import seaborn as sns

# %%
census_occupation_gender_df_2018 = pd.read_pickle("census_occupation_gender_pd_2018.pickle")
census_occupation_gender_df_2017 = pd.read_pickle("census_occupation_gender_pd_2017.pickle")
census_occupation_gender_df_2016 = pd.read_pickle("census_occupation_gender_pd_2016.pickle")
census_occupation_gender_df_2015 = pd.read_pickle("census_occupation_gender_pd_2015.pickle")
census_occupation_gender_df_2014 = pd.read_pickle("census_occupation_gender_pd_2014.pickle")
census_occupation_gender_df_2013 = pd.read_pickle("census_occupation_gender_pd_2013.pickle")
census_occupation_gender_df_2012 = pd.read_pickle("census_occupation_gender_pd_2012.pickle")
census_occupation_gender_df_2011 = pd.read_pickle("census_occupation_gender_pd_2011.pickle")
census_occupation_gender_df_2010 = pd.read_pickle("census_occupation_gender_pd_2010.pickle")

# %%
census_2010_2018_df = pd.concat(
                                [census_occupation_gender_df_2010, census_occupation_gender_df_2011, census_occupation_gender_df_2012, 
                                 census_occupation_gender_df_2013, census_occupation_gender_df_2014, census_occupation_gender_df_2015, 
                                 census_occupation_gender_df_2016, census_occupation_gender_df_2017, census_occupation_gender_df_2018], 
                                     join='inner', axis="rows").set_index('Year','County') # join rows

# %%
census_2010_2018_df.sort_index()
# Out:
#      State County                       Name  Population  Median Age  \
# Year
# 2010    36    005     Bronx County, New York   1386657.0        32.8
# 2010    36    047     Kings County, New York   2508340.0        34.2
# 2010    36    061  New York County, New York   1586698.0        36.4
# 2010    36    081    Queens County, New York   2233841.0        37.3
# 2010    36    085  Richmond County, New York    469363.0        38.7
# 2011    36    005     Bronx County, New York   1392002.0        32.8
# 2011    36    047     Kings County, New York   2532645.0        34.2
# 2011    36    061  New York County, New York   1601948.0        36.5
# 2011    36    081    Queens County, New York   2247848.0        37.4
# 2011    36    085  Richmond County, New York    470467.0        38.6
# 2012    36    005     Bronx County, New York   1408473.0        33.0
# 2012    36    047     Kings County, New York   2565635.0        34.2
# ...

# %%
#census_2010_2018_df.to_pickle('census_2010_2018_df.pickle')

# %%
#census_2010_2018_df.to_csv('census_2010_2018_df.csv', encoding="utf-8", index=False)

# %%
census_2010_2018_df.reset_index(inplace=True)
census_2010_2018_df
# Out:
#     Year State County                       Name  Population  Median Age  \
# 0   2010    36    005     Bronx County, New York   1386657.0        32.8
# 1   2010    36    047     Kings County, New York   2508340.0        34.2
# 2   2010    36    061  New York County, New York   1586698.0        36.4
# 3   2010    36    081    Queens County, New York   2233841.0        37.3
# 4   2010    36    085  Richmond County, New York    469363.0        38.7
# 5   2011    36    005     Bronx County, New York   1392002.0        32.8
# 6   2011    36    047     Kings County, New York   2532645.0        34.2
# 7   2011    36    061  New York County, New York   1601948.0        36.5
# 8   2011    36    081    Queens County, New York   2247848.0        37.4
# 9   2011    36    085  Richmond County, New York    470467.0        38.6
# 10  2012    36    005     Bronx County, New York   1408473.0        33.0
# 11  2012    36    047     Kings County, New York   2565635.0        34.2
# ...

# %%
#census_2010_2018_df.to_pickle('census_2010_2018_panel_index_free_df.pickle')

# %%
#census_2010_2018_df.to_pickle('census_2010_2018_panel_df.pickle')

# %%
#census_2010_2018_df.to_csv('census_2010_2018_panel_df.csv', encoding="utf-8", index=False)

# %%
df = pd.read_pickle('census_2010_2018_df.pickle')
df
# Out:
#      State County                       Name  Population  Median Age  \
# Year
# 2010    36    005     Bronx County, New York   1386657.0        32.8
# 2010    36    047     Kings County, New York   2508340.0        34.2
# 2010    36    061  New York County, New York   1586698.0        36.4
# 2010    36    081    Queens County, New York   2233841.0        37.3
# 2010    36    085  Richmond County, New York    469363.0        38.7
# 2011    36    005     Bronx County, New York   1392002.0        32.8
# 2011    36    047     Kings County, New York   2532645.0        34.2
# 2011    36    061  New York County, New York   1601948.0        36.5
# 2011    36    081    Queens County, New York   2247848.0        37.4
# 2011    36    085  Richmond County, New York    470467.0        38.6
# 2012    36    005     Bronx County, New York   1408473.0        33.0
# 2012    36    047     Kings County, New York   2565635.0        34.2
# ...

# %%
census_2010_2018_outer_df = pd.concat(
                                [census_occupation_gender_df_2010, census_occupation_gender_df_2011, census_occupation_gender_df_2012, 
                                 census_occupation_gender_df_2013, census_occupation_gender_df_2014, census_occupation_gender_df_2015, 
                                 census_occupation_gender_df_2016, census_occupation_gender_df_2017, census_occupation_gender_df_2018], 
                                     join='outer', axis="rows").set_index('Year','County') # join rows
census_2010_2018_outer_df
# Out:
#      State County                       Name  Population  Median Age  \
# Year
# 2010    36    005     Bronx County, New York   1386657.0        32.8
# 2010    36    047     Kings County, New York   2508340.0        34.2
# 2010    36    061  New York County, New York   1586698.0        36.4
# 2010    36    081    Queens County, New York   2233841.0        37.3
# 2010    36    085  Richmond County, New York    469363.0        38.7
# 2011    36    005     Bronx County, New York   1392002.0        32.8
# 2011    36    047     Kings County, New York   2532645.0        34.2
# 2011    36    061  New York County, New York   1601948.0        36.5
# 2011    36    081    Queens County, New York   2247848.0        37.4
# 2011    36    085  Richmond County, New York    470467.0        38.6
# 2012    36    005     Bronx County, New York   1408473.0        33.0
# 2012    36    047     Kings County, New York   2565635.0        34.2
# ...

# %%
census_2010_2018_outer_df.reset_index()
# Out:
#     Year State County                       Name  Population  Median Age  \
# 0   2010    36    005     Bronx County, New York   1386657.0        32.8
# 1   2010    36    047     Kings County, New York   2508340.0        34.2
# 2   2010    36    061  New York County, New York   1586698.0        36.4
# 3   2010    36    081    Queens County, New York   2233841.0        37.3
# 4   2010    36    085  Richmond County, New York    469363.0        38.7
# 5   2011    36    005     Bronx County, New York   1392002.0        32.8
# 6   2011    36    047     Kings County, New York   2532645.0        34.2
# 7   2011    36    061  New York County, New York   1601948.0        36.5
# 8   2011    36    081    Queens County, New York   2247848.0        37.4
# 9   2011    36    085  Richmond County, New York    470467.0        38.6
# 10  2012    36    005     Bronx County, New York   1408473.0        33.0
# 11  2012    36    047     Kings County, New York   2565635.0        34.2
# ...

# %%
census_2010_2018_outer_df.to_pickle('census_2010_2018_outer_index_free_df.pickle')

# %%
census_2010_2018_outer_df.to_csv('census_2010_2018_outer_index_free_df.csv', encoding="utf-8")
